# %%
# KROK 1: Navigácia a vytvorenie nového dashboardu
# ÚKOL: Otvor Databricks workspace, prejdite do sekcie Dashboards a vytvor nový dashboard.
# - Klikni na Dashboards v ľavom bočnom menu.
# - Klikni na tlačidlo "Create dashboard" vpravo hore.
# - Nazvi dashboard (napr. "Agent Insights Dashboard").


# KROK 2: Nastavenie úvodnej obrazovky dashboardu
# ÚKOL: Pridaj záložky Canvas a Data, pripoj datový zdroj a pridaj prvú vizualizáciu.
# - Prejdi na záložku "Canvas" pre pracovnú plochu.
# - Prejdi na "Data" a pripoj SQL dotaz (napr. `SELECT * FROM principal_lab_db.dev_gold.agent_performance_view`).
# - Použi spodné menu na pridanie vizualizácie (napr. stĺpcový graf).

# Príklad SQL dotazu:
# SELECT agent_id, total_premium FROM principal_lab_db.dev_gold.agent_performance_view LIMIT 10


# KROK 3: Vytvorenie a úprava vizualizácií
# ÚKOL: Vytvor SQL dotaz pre vizualizáciu a uprav vzhľad grafu.
# - Použi "Create from SQL" a napíš dotaz pre počet platieb podľa príjmu.
# - Vyber typ grafu (napr. koláčový graf) a prispôsob veľkosť/pozíciu.

# Príklad SQL dotazu:
# SELECT income_level, COUNT(*) as payment_count 
# FROM principal_lab_db.dev_gold.customer_income_distribution 
# GROUP BY income_level


# KROK 4: Finálna podoba dashboardu
# ÚKOL: Pridaj viacero grafov a otestuj Genie AI asistenta.
# - Pridaj grafy pre výkon agentov, rozdelenie produktov a počet platieb.
# - Použi Genie a polož otázku (napr. "Aké sú top 5 agentov podľa prémií?").

# Príklad otázky pre Genie:
# "Aké sú top 5 agentov podľa total_premium?"


# KROK 5: Publikácia a zdieľanie dashboardu
# ÚKOL: Publikuj dashboard a nastav prístupové práva.
# - Klikni na "Publish" pre finálnu verziu.
# - Vyber "Embed credentials" pre zdieľanie s tímom alebo "Individual credentials" pre bezpečnosť.
# - Pridaj používateľov/skupiny do sekcie Permissions.

# Príklad: Pridaj skupinu "data_team" s právom "Can View".


# KROK 6: Plánovanie aktualizácií dashboardu
# ÚKOL: Nastav plánované spúšťanie a aktualizáciu dát.
# - Prejdi na "Add schedule" a nastav dennú aktualizáciu o 8:00 CEST.
# - Vyber SQL Warehouse pre vykonanie dotazov.

# Príklad nastavenia:
# - Frekvencia: Denná
# - Čas: 08:00 CEST
# - Warehouse: Serverless Starter Warehouse


### Dodatočné úlohy z tvojich poznámok:


# KROK 7: Nastavenie obnovovania dát
# ÚKOL: Skontroluj a nastav plán aktualizácie pre live údaje.
# - Prejdi do nastavení dashboardu a pridaj "Schedule" s dennou frekvenciou.
# - Uisti sa, že používatelia vedia o možnom oneskorení dát.

# Poznámka: Pridaj textový widget: "Dáta sú aktualizované denne o 08:00."

# KROK 8: Pridanie globálnych filtrov
# ÚKOL: Vytvor globálny filter pre mesiac a pripoj ho k grafom.
# - Použi "Filter widgets" a pridaj filter na stĺpec (napr. `report_date`).
# - Over, či sa grafy aktualizujú podľa výberu.


# KROK 9: Pridanie popisov
# ÚKOL: Vytvor textové widgety a tooltipy pre grafy.
# - Pridaj textový box s popisom (napr. "Graf zobrazuje výkon agentov").
# - Nastav tooltip pre graf s detailmi (napr. "Total premium za mesiac").

# Príklad textu:
# "Grafs zobrazuje celkové prémiie agentov za posledný mesiac."


# KROK 10: Publikácia finálnej verzie
# ÚKOL: Publikuj dashboard a otestuj zmeny.
# - Klikni na "Publish" pre zverejnenie.
# - Skontroluj, či ostatní vidia správnu verziu (nie draft).
